# %%
# Importing standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# Optional: prevent TensorFlow from using GPU (for debugging or testing)
tf.config.set_visible_devices([], 'GPU')

# Check how many GPUs are available
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import zipfile
from google.colab import drive

drive.mount('/content/drive')  # מחבר את הדרייב, יווצר קישור לנתיב /content/drive
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_file = '/content/drive/MyDrive/archive.zip'
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')

# %%
# !ls /content/dataset
# Out:
# test  train

# %%
# !ls /content/dataset/train
# Out:
# angry  disgust	fear  happy  neutral  sad  surprise

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
    '/content/dataset/train',
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical'
)

test_set = test_datagen.flow_from_directory(
    '/content/dataset/test',
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

cnn = Sequential()

cnn.add(Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[48, 48, 1]))
cnn.add(MaxPooling2D(pool_size=2, strides=2))

cnn.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=2, strides=2))

cnn.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
cnn.add(MaxPooling2D(pool_size=2, strides=2))

cnn.add(Flatten())

cnn.add(Dense(units=128, activation='relu'))
cnn.add(Dropout(0.5))

cnn.add(Dense(units=7, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = cnn.fit(x=training_set, validation_data=test_set, epochs=35)
# Out:
# Epoch 1/35
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 246s 270ms/step - accuracy: 0.2570 - loss: 1.7996 - val_accuracy: 0.3855 - val_loss: 1.5631
# Epoch 2/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 241s 269ms/step - accuracy: 0.3789 - loss: 1.6030 - val_accuracy: 0.4627 - val_loss: 1.3952
# Epoch 3/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 241s 268ms/step - accuracy: 0.4345 - loss: 1.4624 - val_accuracy: 0.4844 - val_loss: 1.3534
# Epoch 4/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 239s 266ms/step - accuracy: 0.4658 - loss: 1.3993 - val_accuracy: 0.5081 - val_loss: 1.2954
# Epoch 5/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 266s 271ms/step - accuracy: 0.4799 - loss: 1.3577 - val_accuracy: 0.5177 - val_loss: 1.2568
# Epoch 6/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 247s 276ms/step - accuracy: 0.4975 - loss: 1.3251 - val_accuracy: 0.5354 - val_loss: 1.2246
# Epoch 7/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 239s 267ms/step - accuracy: 0.5081 - loss: 1.2975 - val_accuracy: 0.5344 - val_loss: 1.2176
# Epoch 8/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 240s 268ms/step - accuracy: 0.5189 - loss: 1.2767 - val_accuracy: 0.5417 - val_loss: 1.1972
# Epoch 9/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 241s 269ms/step - accuracy: 0.5238 - loss: 1.2555 - val_accuracy: 0.5532 - val_loss: 1.1840
# Epoch 10/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 244s 272ms/step - accuracy: 0.5334 - loss: 1.2444 - val_accuracy: 0.5499 - val_loss: 1.1682
# Epoch 11/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 246s 274ms/step - accuracy: 0.5329 - loss: 1.2304 - val_accuracy: 0.5407 - val_loss: 1.1913
# Epoch 12/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 240s 267ms/step - accuracy: 0.5353 - loss: 1.2199 - val_accuracy: 0.5515 - val_loss: 1.1630
# Epoch 13/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 242s 270ms/step - accuracy: 0.5468 - loss: 1.1996 - val_accuracy: 0.5620 - val_loss: 1.1452
# Epoch 14/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 240s 267ms/step - accuracy: 0.5472 - loss: 1.1995 - val_accuracy: 0.5652 - val_loss: 1.1300
# Epoch 15/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 242s 270ms/step - accuracy: 0.5582 - loss: 1.1815 - val_accuracy: 0.5656 - val_loss: 1.1353
# Epoch 16/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 242s 270ms/step - accuracy: 0.5630 - loss: 1.1715 - val_accuracy: 0.5535 - val_loss: 1.1547
# Epoch 17/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 245s 273ms/step - accuracy: 0.5593 - loss: 1.1633 - val_accuracy: 0.5692 - val_loss: 1.1238
# Epoch 18/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 247s 275ms/step - accuracy: 0.5676 - loss: 1.1538 - val_accuracy: 0.5736 - val_loss: 1.1187
# Epoch 19/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 243s 271ms/step - accuracy: 0.5643 - loss: 1.1671 - val_accuracy: 0.5730 - val_loss: 1.1134
# Epoch 20/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 244s 272ms/step - accuracy: 0.5694 - loss: 1.1439 - val_accuracy: 0.5733 - val_loss: 1.1179
# Epoch 21/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 244s 272ms/step - accuracy: 0.5792 - loss: 1.1285 - val_accuracy: 0.5733 - val_loss: 1.1277
# Epoch 22/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 243s 270ms/step - accuracy: 0.5718 - loss: 1.1342 - val_accuracy: 0.5886 - val_loss: 1.0977
# Epoch 23/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 244s 272ms/step - accuracy: 0.5746 - loss: 1.1258 - val_accuracy: 0.5726 - val_loss: 1.1219
# Epoch 24/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 241s 268ms/step - accuracy: 0.5787 - loss: 1.1238 - val_accuracy: 0.5843 - val_loss: 1.0996
# Epoch 25/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 240s 267ms/step - accuracy: 0.5839 - loss: 1.1136 - val_accuracy: 0.5826 - val_loss: 1.1028
# Epoch 26/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 242s 270ms/step - accuracy: 0.5782 - loss: 1.1144 - val_accuracy: 0.5901 - val_loss: 1.1027
# Epoch 27/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 246s 274ms/step - accuracy: 0.5762 - loss: 1.1168 - val_accuracy: 0.5805 - val_loss: 1.1072
# Epoch 28/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 244s 271ms/step - accuracy: 0.5876 - loss: 1.0927 - val_accuracy: 0.5945 - val_loss: 1.0882
# Epoch 29/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 243s 271ms/step - accuracy: 0.5816 - loss: 1.0981 - val_accuracy: 0.5935 - val_loss: 1.0927
# Epoch 30/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 239s 266ms/step - accuracy: 0.5877 - loss: 1.0947 - val_accuracy: 0.5829 - val_loss: 1.1067
# Epoch 31/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 240s 267ms/step - accuracy: 0.5914 - loss: 1.0785 - val_accuracy: 0.5800 - val_loss: 1.1038
# Epoch 32/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 240s 267ms/step - accuracy: 0.5864 - loss: 1.0954 - val_accuracy: 0.5844 - val_loss: 1.1018
# Epoch 33/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 245s 273ms/step - accuracy: 0.5912 - loss: 1.0741 - val_accuracy: 0.5924 - val_loss: 1.0917
# Epoch 34/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 241s 269ms/step - accuracy: 0.5929 - loss: 1.0752 - val_accuracy: 0.5878 - val_loss: 1.0981
# Epoch 35/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 245s 273ms/step - accuracy: 0.5956 - loss: 1.0724 - val_accuracy: 0.5925 - val_loss: 1.0919

# %%
cnn.save('karin_final_best.keras')

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('/content/drive/MyDrive/karin_final_best.keras')
